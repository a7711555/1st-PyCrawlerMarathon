# %% [markdown]
# 目前程式中的 proxy_ips 是手動輸入的，請根據 https://free-proxy-list.net/ 寫一個可自動化抓取可用 Proxy 的 proxy_ips。

# %%
import random

from bs4 import BeautifulSoup
import requests

proxy_ips = []

url = 'https://free-proxy-list.net/'
r = requests.get(url)
soup = BeautifulSoup(r.text)

table = soup.find('tbody')

for row in table:
    td = row.find_all('td')
    ip = td[0].text
    port = td[1].text
    proxy_ips.append(f'http://{ip}:{port}')

print(proxy_ips)
# Out:
# ['http://150.242.34.116:53281', 'http://139.180.163.43:8080', 'http://5.135.181.83:80', 'http://51.38.184.52:8080', 'http://41.164.247.250:38460', 'http://41.65.43.228:8080', 'http://5.9.202.163:1080', 'http://78.46.40.146:8118', 'http://77.58.96.177:80', 'http://200.89.174.64:8080', 'http://200.89.178.208:3128', 'http://92.222.180.156:8080', 'http://115.127.109.2:45067', 'http://47.91.44.244:8080', 'http://217.61.0.167:8080', 'http://150.242.33.97:53281', 'http://27.147.136.178:47678', 'http://201.55.160.18:3128', 'http://181.168.206.106:38024', 'http://46.4.20.90:1080', 'http://200.89.178.209:8080', 'http://138.117.54.129:48243', 'http://13.210.94.201:80', 'http://186.42.124.130:65301', 'http://103.243.82.198:37358', 'http://210.56.244.230:8080', 'http://85.187.17.39:53281', 'http://173.212.202.65:80', 'http://85.10.219.102:1080', 'http://200.73.128.149:3128', 'http://190.152.12.54:41031', 'http://159.203.62.127:3128', 'http://190.152.36.102:44340', 'http://80.188.239.106:39271', 'http://165.227.46.197:8080', 'http://138.197.157.60:3128', 'http://138.197.157.45:8080', 'http://191.97.37.12:48930', 'http://200.236.221.242:36729', 'http://138.197.157.44:8080', 'http://45.173.129.29:8080', 'http://103.221.254.2:40576', 'http://46.4.96.137:3128', 'http://193.68.135.123:59278', 'http://201.64.22.50:8081', 'http://190.214.13.90:21776', 'http://194.167.44.91:80', 'http://177.222.251.162:33834', 'http://138.197.157.32:8080', 'http://169.57.157.146:8123', 'http://194.26.180.142:80', 'http://207.154.231.217:3128', 'http://51.79.53.10:80', 'http://94.130.125.222:1080', 'http://200.73.129.85:3128', 'http://95.128.144.1:51449', 'http://159.8.114.34:8123', 'http://200.255.122.170:8080', 'http://144.217.163.138:8080', 'http://170.239.85.225:8080', 'http://177.106.169.14:3128', 'http://178.169.196.87:48834', 'http://207.154.231.211:3128', 'http://80.187.140.26:8080', 'http://77.68.4.202:80', 'http://88.198.50.103:8080', 'http://200.152.78.48:38543', 'http://186.159.3.41:30334', 'http://185.220.101.63:3128', 'http://77.48.22.59:38974', 'http://123.49.41.129:23500', 'http://52.139.3.203:80', 'http://190.152.223.2:37994', 'http://179.191.118.146:8080', 'http://159.8.114.37:8123', 'http://88.198.24.108:8080', 'http://177.125.20.35:40744', 'http://207.154.231.213:8080', 'http://5.189.133.231:80', 'http://176.9.119.170:8080', 'http://176.9.75.42:8080', 'http://143.255.52.25:44298', 'http://181.211.38.62:47911', 'http://201.64.22.51:8081', 'http://138.197.145.103:8080', 'http://203.202.245.58:80', 'http://81.200.63.108:60579', 'http://158.255.23.146:35168', 'http://138.68.165.154:3128', 'http://207.154.231.216:3128', 'http://165.227.36.147:8080', 'http://200.225.140.130:61021', 'http://181.129.66.138:55679', 'http://207.154.231.212:8080', 'http://169.57.157.148:80', 'http://203.202.245.62:80', 'http://164.77.147.93:53281', 'http://93.185.96.60:41003', 'http://78.46.91.48:1080', 'http://94.230.158.37:39509', 'http://87.198.52.243:8080', 'http://45.143.188.253:8080', 'http://102.165.69.154:8080', 'http://103.9.191.223:8080', 'http://103.109.2.42:8080', 'http://96.30.53.124:3128', 'http://176.36.164.240:48039', 'http://85.10.219.100:1080', 'http://197.234.179.102:3128', 'http://124.41.243.31:30978', 'http://168.194.15.142:48876', 'http://119.63.132.90:30759', 'http://217.23.69.146:8080', 'http://84.214.150.146:8080', 'http://202.182.121.205:8080', 'http://183.91.33.41:8087', 'http://118.174.220.32:51399', 'http://5.23.102.194:52803', 'http://139.162.78.109:8080', 'http://139.59.64.9:8080', 'http://162.243.108.129:3128', 'http://139.59.99.63:3128', 'http://95.79.55.196:53281', 'http://182.253.115.90:8080', 'http://173.192.128.238:8123', 'http://45.55.9.218:8080', 'http://188.166.83.34:3128', 'http://178.62.193.19:3128', 'http://139.59.53.107:3128', 'http://188.226.141.211:3128', 'http://139.59.101.223:8080', 'http://190.151.94.2:46615', 'http://85.10.219.97:1080', 'http://198.199.119.119:3128', 'http://139.59.62.255:3128', 'http://188.166.83.20:3128',  ...

# %%
for i in range(10):
    ip = random.choice(proxy_ips)
    print('Use', ip)
    try:
        resp = requests.get('http://ip.filefab.com/index.php',
                        proxies={'http': ip}, timeout=10)
        soup = BeautifulSoup(resp.text, 'lxml')
        print(soup.find('h1', id='ipd').text.strip())
    except Exception as e:
        print('Fail: ', e)
# Out:
# Use http://138.197.157.60:3128
# Your IP address: 138.197.157.60
# Use http://201.64.22.51:8081
# Your IP address: 201.64.22.50
# Use http://78.46.91.48:1080
# Fail:  'NoneType' object has no attribute 'text'
# Use http://1.228.6.41:8080
# Fail:  HTTPConnectionPool(host='1.228.6.41', port=8080): Max retries exceeded with url: http://ip.filefab.com/index.php (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x00000225510AEA48>, 'Connection to 1.228.6.41 timed out. (connect timeout=10)'))
# Use http://178.46.153.202:3128
# Fail:  HTTPConnectionPool(host='178.46.153.202', port=3128): Max retries exceeded with url: http://ip.filefab.com/index.php (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x00000225510AEF48>, 'Connection to 178.46.153.202 timed out. (connect timeout=10)'))
# Use http://103.66.47.97:8080
# Fail:  HTTPConnectionPool(host='103.66.47.97', port=8080): Max retries exceeded with url: http://ip.filefab.com/index.php (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x00000225510BA1C8>, 'Connection to 103.66.47.97 timed out. (connect timeout=10)'))
# Use http://167.172.252.251:3128
# Your IP address: 167.172.252.251
# Use http://194.26.180.142:80
# Your IP address: 194.26.180.142
# Use http://27.50.18.116:8080
# Your IP address: 27.50.18.116
# Use http://182.52.51.59:38238
# Your IP address: 182.52.51.59
