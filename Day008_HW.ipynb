# %% [markdown]
# 利用 Request + BeatifulSoup 爬取下列兩個網站內容並解析：
#
# Dcared 網址： https://www.dcard.tw/f
#
# 知乎： https://www.zhihu.com/explore

# %%
# 1. Request 取回之後該怎麼取出資料，資料型態是什麼？

'''
取得 response 後可以透過屬性 text 取出成字串，視資料結構做處理
'''
# Out:
# '\n取得 response 後可以透過屬性 text 取出成字串，視資料結構做處理\n'

# %%
# 2. 為什麼要使用 BeatifulSoup 處理？處理後的型態是什麼？

'''
若 response 回來的資料結構是 HTML，處理上不容易，透過 BueatifulSoup 回傳一個 bs4.BeautifulSoupbs4 的 class，利用其屬性及方法處理取得的資料
'''
# Out:
# '\n若 response 回來的資料結構是 HTML，處理上不容易，透過 BueatifulSoup 回傳一個 bs4.BeautifulSoupbs4 的 class，利用其屬性及方法處理取得的資料\n'

# %%
# 3. 

import requests
from bs4 import BeautifulSoup

url = 'https://www.zhihu.com/explore'
headers = {'user-agent': 'my-app/0.0.1'}

html_doc = requests.get(url, headers=headers).text

soup = BeautifulSoup(html_doc)
# Out:
# \u002F\u002Fpic3.zhimg.com\u002F50\u002Fv2-70571dd7fd6908102b930ddb554e558b_hd.jpg","urlToken":"zhishujijin"},"anquanbixiuke":{"startAt":1579276800,"name":"为人父母的安全必修课","title":"为人父母的安全必修课","color":"#69BC22","banner":"https:\u002F\u002Fpic2.zhimg.com\u002F50\u002Fv2-a08bf4aab090bf138199e25a0207c2ed_hd.jpg","tinyBanner":"https:\u002F\u002Fpic3.zhimg.com\u002F50\u002Fv2-c63880a848ac00031797de705593d62b_hd.jpg","endAt":1580486340,"url":"\u002Froundtables\u002Fexplore\u002Fcards\u002Froundtable\u002Fanquanbixiuke","followersCount":462,"intro":"养育一个孩子从婴儿到成年，有多不容易？对孩子来说，春节团圆之际、日常生活之中，又潜藏着哪些易被忽视的危险？ 为人父母，我们有哪些安全必修课？","isFollowing":false,"guests":[{"avatarUrl":"https:\u002F\u002Fpic1.zhimg.com\u002F50\u002Fv2-aec1173221590800b8fd28d5da8ddae0_hd.jpg"},{"avatarUrl":"https:\u002F\u002Fpic3.zhimg.com\u002F50\u002Fv2-cd7054e35870176e384288f6d5caed74_hd.jpg"},{"avatarUrl":"https:\u002F\u002Fpic2.zhimg.com\u002F50\u002Fv2-3a2f23c1cb182f5f055a1e02d6e97257_hd.jpg"},{"avatarUrl":"https:\u002F\u002Fpic4.zhimg.com\u002F50\u002Fv2-30bf7659b13f5ef68c522afaf98ba717_hd.jpg"},{"avatarUrl":"https:\u002F\u002Fpic3.zhimg.com\u002F50\u002Fv2-f80c1edcfc1d2842c2d3eca1a084af5b_hd.jpg"},{"avatarUrl":"https:\u002F\u002Fpic2.zhimg.com\u002F50\u002Fv2-18fc85cf1aae5679de51d42c4589384e_hd.jpg"},{"avatarUrl":"https:\u002F\u002Fpic4.zhimg.com\u002F50\u002Fb44a91b50_hd.jpg"}],"questions":[{"followerCount":12786,"title":"生活中有哪些普遍存在、不易察觉而十分危险的儿童安全隐患？如何避免？","url":"https:\u002F\u002Fwww.zhihu.com\u002Fquestion\u002F47022148","type":"question","id":47022148,"answerCount":456},{"followerCount":64,"title":"如果有一所学校，专门教父母如何成为父母，你认为应该开设哪些必修课？","url":"https:\u002F\u002Fwww.zhihu.com\u002Fquestion\u002F367109399","type":"question","id":367109399,"answerCount":38},{"followerCount":51,"title":"过年带宝宝走亲戚时需要注意什么？","url":"https:\u002F\u002Fwww.zhihu.com\u002Fquestion\u002F366766116","type":"question","id":366766116,"answerCount":24}],"logo":"https:\u002F\u002Fpic1.zhimg.com\u002F50\u002Fv2-00f8805ec1d10c26f09a8f6a878c77ed_hd.jpg","urlToken":"anquanbixiuke"}},"order":["genangtanwu","nidejiaxiangyouneixi","zhishujijin","anquanbixiuke"]},"collections":{"20140680":{"favitems":[{"content":{"isCollapsed":false,"author":{"avatarUrlTemplate":"https:\u002F\u002Fpic4.zhimg.com\u002Fv2-7c1dfc4e196e594f960a43a3e1ebeb66_{size}.jpg","name":"Hello桑尼","headline":"专注于时间管理&amp;高效学习","gender":1,"userType":"people","urlToken":"cai-yao-hui-75","isAdvertiser":false,"avatarUrl":"https:\u002F\u002Fpic4.zhimg.com\u002Fv2-7c1dfc4e196e594f960a43a3e1ebeb66_is.jpg","isOrg":false,"type":"people","url":"http:\u002F\u002Fwww.zhihu.com\u002Fapi\u002Fv4\u002Fpeople\u002F5a05d0631e4f62a66af79f19e2add365","badge":[],"id":"5a05d0631e4f62a66af79f19e2add365"},"url":"http:\u002F\u002Fwww.zhihu.com\u002Fapi\u002Fv4\u002Fanswers\u002F967305094","question":{"questionType":"normal","title":"对你帮助最大的书是什么?","url":"http:\u002F\u002Fwww.zhihu.com\u002Fapi\u002Fv4\u002Fquestions\u002F333995687","created":1562622309,"type":"question","id":333995687,"updatedTime":1566028832},"id":967305094,"excerpt":"\u003Cb\u003E 与其浪费时间去看完100本很一般的书，不如认真花时间去读完1本高质量的书。\u003C\u002Fb\u003E在过去三年里，我读了三百多本书，质量参差不齐，但是确实有遇到几本让我有\u003Cb\u003E跪感、对我影响非常大\u003C\u002Fb\u003E的书，这些书来自于多个领域。今天我就把它们整理成一套书单分享给大家。书单的内…","updatedTime":1579312367,"commentCount":281,"extras":"","answerType":"answer","createdTime":1578486817,"isCopyable":false,"type":"answer","thumbnail":"https:\u002F\u002Fpic1.zhimg.com\u002Fv2-3aaccad20e8f66e31a3c430d5cfb058a_200x112.jpg","voteupCount":10139}},{"content":{"isCollapsed":false,"author":{"avatarUrlTemplate":"https:\u002F\u002Fpic4.zhimg.com\u002Faadd7b895_{size}.jpg","name":"匿名用户","headline":"","userType":"people","urlToken":"","isAdvertiser":false,"avatarUrl":"https:\u002F\u002Fpic4.zhimg.com\u002Faadd7b895_is.jpg","isOrg":false,"type":"people","url":"http:\u002F\u002Fwww.zhihu.com\u002Fapi\u002Fv4\u002Fpeople\u002F0","badge":[],"id":"0"},"url":"http:\u002F\u002Fwww.zhihu.com\u002Fapi\u002Fv4\u002Fanswers\u002F958126348","question":{"question ...
